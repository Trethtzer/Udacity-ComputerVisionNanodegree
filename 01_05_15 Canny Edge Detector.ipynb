# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %matplotlib inline

# Read in the image
image = cv2.imread('1_2_Convolutional_Filters_Edge_Detection/images/sunflower.jpg')

# Make a copy of the image
image_copy = np.copy(image)

# Change color to RGB
image_copy = cv2.cvtColor(image_copy,cv2.COLOR_BGR2RGB)

#plt.imshow(image_copy)

gray = cv2.cvtColor(image_copy,cv2.COLOR_RGB2GRAY)
plt.imshow(gray, cmap='gray')

# %% [markdown]
# ### Implement Canny edge detection

# %%
#Define lower and upper thresholds for hysteresis
lower = 120
upper = 240

edges = cv2.Canny(gray,lower,upper)

plt.imshow(edges, cmap='gray')

# %%
# Try Canny using "wide" and "tight" thresholds

wide = cv2.Canny(gray,30,100)
tight = cv2.Canny(gray,180,240)

# Display the images
f, (ax1,ax2) = plt.subplots(1,2,figsize=(10,30))

ax1.set_title('wide')
ax1.imshow(wide, cmap='gray')

ax2.set_title('tight')
ax2.imshow(tight, cmap='gray')
