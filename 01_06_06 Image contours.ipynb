# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %matplotlib inline

# Read in thte image
image = cv2.imread('1_3_Types_of_Features_Image_Segmentation/images/thumbs_up_down.jpg')

# Make a copy of the image
image_copy = np.copy(image)

# Change color to RGB ( from BGR)
image_copy = cv2.cvtColor(image_copy, cv2.COLOR_BGR2RGB)

gray = cv2.cvtColor(image_copy, cv2.COLOR_RGB2GRAY)

f, ax = plt.subplots(1,1,figsize=(5,5))
ax.imshow(gray, cmap='gray')

# %% [markdown]
# ### Produce a binary image for finding contours

# %%
# Create a binary thresholded image
retval, binary = cv2.threshold(gray, 225, 255, cv2.THRESH_BINARY_INV)

f, ax = plt.subplots(1,1,figsize=(5,5))
ax.imshow(binary,cmap='gray')

# %% [markdown]
# ### Find and draw the contours

# %%
# Find contours from thresholded image
contours, hierarchy = cv2.findContours(binary, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
                              
# Draw all contours on a copy of the original image
image_copy2 = np.copy(image_copy)
all_contours = cv2.drawContours(image_copy2, contours, -1, (0,255,0), 1)

f, ax = plt.subplots(1,1,figsize=(15,15))
ax.imshow(all_contours)
